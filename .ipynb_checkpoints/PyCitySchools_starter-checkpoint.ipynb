# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school = school_data_complete["school_name"].unique()
total_schools = len(school)
total_schools

total_student = len(school_data_complete)

district_real_student_count = student_data['student_name'].count()



list_budget = school_data_complete.groupby("school_name").mean()
total_budget = list_budget["budget"].sum()
#total_budget = '$[:,.2f]'.format(total_budget) didn't work for some reason
#total_budget = '$[:,]'.format(total_budget) neither did this, both printed wrong things
total_budget = '${:,.2f}'.format(total_budget)


average_math_score = school_data_complete['math_score'].mean()
average_reading_score = school_data_complete['reading_score'].mean()

#passing grades  

passing_reading = school_data_complete.loc[school_data_complete['reading_score'] >= 70,:]
reading_percentage = passing_reading['reading_score'].count()/ total_student * 100
reading_percentage

passing_math = school_data_complete.loc[school_data_complete['math_score'] >= 70,:]
math_percentage = passing_math['math_score'].count()/ total_student * 100
math_percentage

total_passing = student_data[(student_data['math_score'] >= 70) & (student_data['reading_score'] >= 70)]['student_name'].count()/district_real_student_count * 100
#total_passing = student_data[(student_data['math_score']>=70)&(student_data['reading_score']>=70)]['student_name'].count()/district_real_student_count
#total_passing = (int(passing_reading + passing_math)/2)

total_student = '{:,.0f}'.format(total_student)

district_summaryDF = pd.DataFrame({"Total Schools" : [total_schools, 1], "Total Students" : [total_student, 1],
                         "Total Budget": [total_budget, 1],
                           "Average Math Score" : [average_math_score, 1], "Average Reading Score" : [average_reading_score, 1],
                          "% Passing Math" : [math_percentage, 1], "% Passing Reading" : [reading_percentage,1], 
                          "% Overall Passing Rate" : [total_passing,1]})

summary = district_summaryDF.drop([1])

summary
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Overall Passing Rate
# 0               65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
school_data_complete.set_index('school_name')['budget']/school_data_complete.set_index('student_name')['budget'].tail()
school_data_complete.drop_duplicates()
clean_school_data = school_data_complete.drop_duplicates()
clean_school_data
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
# [39170 rows x 11 columns]

# %%
school_pop = clean_school_data['school_name'].value_counts()

school_type = school_data.set_index(['school_name'])['type']

school_budget = school_data.set_index('school_name')['budget']

per_student = school_budget/school_pop

school = clean_school_data.groupby('school_name')
average_math = school['math_score'].mean()
average_reading = school['reading_score'].mean()

passing_math = clean_school_data.loc[clean_school_data['math_score'] >= 70,:].groupby('school_name')
passing_math = passing_math['Student ID'].count()/school_pop 

passing_reading = clean_school_data.loc[clean_school_data['reading_score'] >= 70,:].groupby('school_name')
passing_reading = passing_reading['Student ID'].count()/school_pop 

all_passing = clean_school_data.loc[(clean_school_data['reading_score']>=70) & (clean_school_data['math_score']>=70)].groupby('school_name')
all_passing = all_passing['Student ID'].count()/school_pop * 100

# student_per_school = clean_school_data.set_index('school_name')['student_name'].count()

# school_budget = clean_school_data.set_index('school_name')['budget']

# student_budget = clean_school_data.set_index('school_name')['budget']/clean_school_data.set_index('student_name')['budget']


# average_math_score = school_group["math_score"].mean()
# average_reading_score = school_group["reading_score"].mean()


# passing_math = clean_school_data.loc[clean_school_data['math_score'] >= 70,:].groupby('school_name')
# passing_math = passing_math['Student ID'].count()/student_per_school * 100


# passing_reading = clean_school_data.loc[clean_school_data['reading_score'] >= 70,:].groupby('school_name')
# passing_reading = passing_reading['Student ID'].count()/student_per_school * 100


# all_passing = clean_school_data.loc[(clean_school_data['reading_score']>=70) & (school_data_complete['math_score']>=70)].groupby('school_name')
# all_passing = all_passing['Student ID'].count()/student_per_school

summary  = ({"School Type" : school_type,
                               "Total Students" : school_pop,
            "Total School Budget": school_budget,
             "Per Student Budget": per_student,
             "Average Math Score": average_math,
             "Average Reading Score": average_reading,
             "% Passing Math": passing_math,
             "% Passing Reading": passing_reading,
             "% Overall Passing": all_passing
             
            
                            })
#summary
summaryDF = pd.DataFrame(summary)
summaryDF.style.format({'Total Students': '{:,}', 
                          "Total School Budget": "${:,}", 
                          "Per Student Budget": "${:.0f}",
                          'Average Math Score': "{:.1f}", 
                          'Average Reading Score': "{:.1f}", 
                          "% Passing Math": "{:.1%}", 
                          "% Passing Reading": "{:.1%}", 
                          "Overall Passing Rate": "{:.1%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adlevel0_row0" class="row_heading level0 row0" >Bailey High School</th>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow0_col0" class="data row0 col0" >District</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow0_col1" class="data row0 col1" >4,976</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow0_col2" class="data row0 col2" >$3,124,928</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow0_col3" class="data row0 col3" >$628</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow0_col4" class="data row0 col4" >77.0</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow0_col5" class="data row0 col5" >81.0</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow0_col6" class="data row0 col6" >66.7%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow0_col7" class="data row0 col7" >81.9%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow0_col8" class="data row0 col8" >54.642283</td>
#             </tr>
#             <tr>
#                         <th id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adlevel0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow1_col0" class="data row1 col0" >Charter</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow1_col1" class="data row1 col1" >1,858</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow1_col2" class="data row1 col2" >$1,081,356</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow1_col3" class="data row1 col3" >$582</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow1_col4" class="data row1 col4" >83.1</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow1_col5" class="data row1 col5" >84.0</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow1_col6" class="data row1 col6" >94.1%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow1_col7" class="data row1 col7" >97.0%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow1_col8" class="data row1 col8" >91.334769</td>
#             </tr>
#             <tr>
#                         <th id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adlevel0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow2_col0" class="data row2 col0" >District</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow2_col1" class="data row2 col1" >2,949</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow2_col2" class="data row2 col2" >$1,884,411</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow2_col3" class="data row2 col3" >$639</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow2_col4" class="data row2 col4" >76.7</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow2_col5" class="data row2 col5" >81.2</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow2_col6" class="data row2 col6" >66.0%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow2_col7" class="data row2 col7" >80.7%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow2_col8" class="data row2 col8" >53.204476</td>
#             </tr>
#             <tr>
#                         <th id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adlevel0_row3" class="row_heading level0 row3" >Ford High School</th>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow3_col0" class="data row3 col0" >District</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow3_col1" class="data row3 col1" >2,739</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow3_col2" class="data row3 col2" >$1,763,916</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow3_col3" class="data row3 col3" >$644</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow3_col4" class="data row3 col4" >77.1</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow3_col5" class="data row3 col5" >80.7</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow3_col6" class="data row3 col6" >68.3%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow3_col7" class="data row3 col7" >79.3%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow3_col8" class="data row3 col8" >54.289887</td>
#             </tr>
#             <tr>
#                         <th id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adlevel0_row4" class="row_heading level0 row4" >Griffin High School</th>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow4_col0" class="data row4 col0" >Charter</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow4_col1" class="data row4 col1" >1,468</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow4_col2" class="data row4 col2" >$917,500</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow4_col3" class="data row4 col3" >$625</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow4_col4" class="data row4 col4" >83.4</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow4_col5" class="data row4 col5" >83.8</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow4_col6" class="data row4 col6" >93.4%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow4_col7" class="data row4 col7" >97.1%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow4_col8" class="data row4 col8" >90.599455</td>
#             </tr>
#             <tr>
#                         <th id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adlevel0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow5_col0" class="data row5 col0" >District</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow5_col1" class="data row5 col1" >4,635</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow5_col2" class="data row5 col2" >$3,022,020</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow5_col3" class="data row5 col3" >$652</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow5_col4" class="data row5 col4" >77.3</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow5_col5" class="data row5 col5" >80.9</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow5_col6" class="data row5 col6" >66.8%</td>
#                         <td id="T_fc7ec7bc_c8ec_11eb_97e0_04d9f5f899adrow5_col7" class="data row5 col7" >80.9%</td>

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_school = summaryDF.sort_values(by = ["% Overall Passing"], ascending = False)
top_school.head().style.format({'Total Students': '{:,}', 
                       "Total School Budget": "${:,}", 
                       "Per Student Budget": "${:.0f}", 
                       "% Passing Math": "{:.1%}", 
                       "% Passing Reading": "{:.1%}", 
                       "% Overall Passing Rate": "{:.1%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adlevel0_row0" class="row_heading level0 row0" >Cabrera High School</th>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow0_col0" class="data row0 col0" >Charter</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow0_col1" class="data row0 col1" >1,858</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow0_col2" class="data row0 col2" >$1,081,356</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow0_col3" class="data row0 col3" >$582</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow0_col4" class="data row0 col4" >83.061895</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow0_col5" class="data row0 col5" >83.975780</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow0_col6" class="data row0 col6" >94.1%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow0_col7" class="data row0 col7" >97.0%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow0_col8" class="data row0 col8" >91.334769</td>
#             </tr>
#             <tr>
#                         <th id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adlevel0_row1" class="row_heading level0 row1" >Thomas High School</th>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow1_col0" class="data row1 col0" >Charter</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow1_col1" class="data row1 col1" >1,635</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow1_col2" class="data row1 col2" >$1,043,130</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow1_col3" class="data row1 col3" >$638</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow1_col4" class="data row1 col4" >83.418349</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow1_col5" class="data row1 col5" >83.848930</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow1_col6" class="data row1 col6" >93.3%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow1_col7" class="data row1 col7" >97.3%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow1_col8" class="data row1 col8" >90.948012</td>
#             </tr>
#             <tr>
#                         <th id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adlevel0_row2" class="row_heading level0 row2" >Griffin High School</th>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow2_col0" class="data row2 col0" >Charter</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow2_col1" class="data row2 col1" >1,468</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow2_col2" class="data row2 col2" >$917,500</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow2_col3" class="data row2 col3" >$625</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow2_col4" class="data row2 col4" >83.351499</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow2_col5" class="data row2 col5" >83.816757</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow2_col6" class="data row2 col6" >93.4%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow2_col7" class="data row2 col7" >97.1%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow2_col8" class="data row2 col8" >90.599455</td>
#             </tr>
#             <tr>
#                         <th id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adlevel0_row3" class="row_heading level0 row3" >Wilson High School</th>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow3_col0" class="data row3 col0" >Charter</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow3_col1" class="data row3 col1" >2,283</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow3_col2" class="data row3 col2" >$1,319,574</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow3_col3" class="data row3 col3" >$578</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow3_col4" class="data row3 col4" >83.274201</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow3_col5" class="data row3 col5" >83.989488</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow3_col6" class="data row3 col6" >93.9%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow3_col7" class="data row3 col7" >96.5%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow3_col8" class="data row3 col8" >90.582567</td>
#             </tr>
#             <tr>
#                         <th id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adlevel0_row4" class="row_heading level0 row4" >Pena High School</th>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow4_col0" class="data row4 col0" >Charter</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow4_col1" class="data row4 col1" >962</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow4_col2" class="data row4 col2" >$585,858</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow4_col3" class="data row4 col3" >$609</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow4_col4" class="data row4 col4" >83.839917</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow4_col5" class="data row4 col5" >84.044699</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow4_col6" class="data row4 col6" >94.6%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow4_col7" class="data row4 col7" >95.9%</td>
#                         <td id="T_67ed7e0b_c8ed_11eb_b295_04d9f5f899adrow4_col8" class="data row4 col8" >90.540541</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_school = summaryDF.sort_values(by = ["% Overall Passing"], ascending = True)
bottom_school.head().style.format({'Total Students': '{:,}', 
                       "Total School Budget": "${:,}", 
                       "Per Student Budget": "${:.0f}", 
                       "% Passing Math": "{:.1%}", 
                       "% Passing Reading": "{:.1%}", 
                       "% Overall Passing Rate": "{:.1%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adlevel0_row0" class="row_heading level0 row0" >Rodriguez High School</th>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow0_col0" class="data row0 col0" >District</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow0_col1" class="data row0 col1" >3,999</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow0_col2" class="data row0 col2" >$2,547,363</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow0_col3" class="data row0 col3" >$637</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow0_col4" class="data row0 col4" >76.842711</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow0_col5" class="data row0 col5" >80.744686</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow0_col6" class="data row0 col6" >66.4%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow0_col7" class="data row0 col7" >80.2%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow0_col8" class="data row0 col8" >52.988247</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adlevel0_row1" class="row_heading level0 row1" >Figueroa High School</th>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow1_col0" class="data row1 col0" >District</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow1_col1" class="data row1 col1" >2,949</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow1_col2" class="data row1 col2" >$1,884,411</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow1_col3" class="data row1 col3" >$639</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow1_col4" class="data row1 col4" >76.711767</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow1_col5" class="data row1 col5" >81.158020</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow1_col6" class="data row1 col6" >66.0%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow1_col7" class="data row1 col7" >80.7%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow1_col8" class="data row1 col8" >53.204476</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adlevel0_row2" class="row_heading level0 row2" >Huang High School</th>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow2_col0" class="data row2 col0" >District</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow2_col1" class="data row2 col1" >2,917</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow2_col2" class="data row2 col2" >$1,910,635</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow2_col3" class="data row2 col3" >$655</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow2_col4" class="data row2 col4" >76.629414</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow2_col5" class="data row2 col5" >81.182722</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow2_col6" class="data row2 col6" >65.7%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow2_col7" class="data row2 col7" >81.3%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow2_col8" class="data row2 col8" >53.513884</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adlevel0_row3" class="row_heading level0 row3" >Hernandez High School</th>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow3_col0" class="data row3 col0" >District</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow3_col1" class="data row3 col1" >4,635</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow3_col2" class="data row3 col2" >$3,022,020</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow3_col3" class="data row3 col3" >$652</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow3_col4" class="data row3 col4" >77.289752</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow3_col5" class="data row3 col5" >80.934412</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow3_col6" class="data row3 col6" >66.8%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow3_col7" class="data row3 col7" >80.9%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow3_col8" class="data row3 col8" >53.527508</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adlevel0_row4" class="row_heading level0 row4" >Johnson High School</th>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow4_col0" class="data row4 col0" >District</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow4_col1" class="data row4 col1" >4,761</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow4_col2" class="data row4 col2" >$3,094,650</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow4_col3" class="data row4 col3" >$650</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow4_col4" class="data row4 col4" >77.072464</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow4_col5" class="data row4 col5" >80.966394</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow4_col6" class="data row4 col6" >66.1%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow4_col7" class="data row4 col7" >81.2%</td>
#                         <td id="T_6a3137a1_c8ed_11eb_b247_04d9f5f899adrow4_col8" class="data row4 col8" >53.539172</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
ninth_math = clean_school_data.loc[clean_school_data['grade'] == '9th'].groupby('school_name')["math_score"].mean()
tenth_math = clean_school_data.loc[clean_school_data['grade'] == '10th'].groupby('school_name')["math_score"].mean()
eleventh_math = clean_school_data.loc[clean_school_data['grade'] == '11th'].groupby('school_name')["math_score"].mean()
twelfth_math = clean_school_data.loc[clean_school_data['grade'] == '12th'].groupby('school_name')["math_score"].mean()

math_scores = pd.DataFrame({
        "9th": ninth_math,
        "10th": tenth_math,
        "11th": eleventh_math,
        "12th": twelfth_math
})
math_scores = math_scores[['9th', '10th', '11th', '12th']]
math_scores.index.name = "School"


math_scores.style.format({'9th': '{:.1f}', 
                          "10th": '{:.1f}', 
                          "11th": "{:.1f}", 
                          "12th": "{:.1f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_96def0b4_c8a5_11eb_b842_04d9f5f899ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >9th</th>        <th class="col_heading level0 col1" >10th</th>        <th class="col_heading level0 col2" >11th</th>        <th class="col_heading level0 col3" >12th</th>    </tr>    <tr>        <th class="index_name level0" >School</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row0" class="row_heading level0 row0" >Bailey High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow0_col0" class="data row0 col0" >77.1</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow0_col1" class="data row0 col1" >77.0</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow0_col2" class="data row0 col2" >77.5</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow0_col3" class="data row0 col3" >76.5</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow1_col0" class="data row1 col0" >83.1</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow1_col1" class="data row1 col1" >83.2</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow1_col2" class="data row1 col2" >82.8</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow1_col3" class="data row1 col3" >83.3</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow2_col0" class="data row2 col0" >76.4</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow2_col1" class="data row2 col1" >76.5</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow2_col2" class="data row2 col2" >76.9</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow2_col3" class="data row2 col3" >77.2</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row3" class="row_heading level0 row3" >Ford High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow3_col0" class="data row3 col0" >77.4</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow3_col1" class="data row3 col1" >77.7</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow3_col2" class="data row3 col2" >76.9</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow3_col3" class="data row3 col3" >76.2</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row4" class="row_heading level0 row4" >Griffin High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow4_col0" class="data row4 col0" >82.0</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow4_col1" class="data row4 col1" >84.2</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow4_col2" class="data row4 col2" >83.8</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow4_col3" class="data row4 col3" >83.4</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow5_col0" class="data row5 col0" >77.4</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow5_col1" class="data row5 col1" >77.3</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow5_col2" class="data row5 col2" >77.1</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow5_col3" class="data row5 col3" >77.2</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row6" class="row_heading level0 row6" >Holden High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow6_col0" class="data row6 col0" >83.8</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow6_col1" class="data row6 col1" >83.4</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow6_col2" class="data row6 col2" >85.0</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow6_col3" class="data row6 col3" >82.9</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row7" class="row_heading level0 row7" >Huang High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow7_col0" class="data row7 col0" >77.0</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow7_col1" class="data row7 col1" >75.9</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow7_col2" class="data row7 col2" >76.4</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow7_col3" class="data row7 col3" >77.2</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row8" class="row_heading level0 row8" >Johnson High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow8_col0" class="data row8 col0" >77.2</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow8_col1" class="data row8 col1" >76.7</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow8_col2" class="data row8 col2" >77.5</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow8_col3" class="data row8 col3" >76.9</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row9" class="row_heading level0 row9" >Pena High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow9_col0" class="data row9 col0" >83.6</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow9_col1" class="data row9 col1" >83.4</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow9_col2" class="data row9 col2" >84.3</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow9_col3" class="data row9 col3" >84.1</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row10" class="row_heading level0 row10" >Rodriguez High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow10_col0" class="data row10 col0" >76.9</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow10_col1" class="data row10 col1" >76.6</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow10_col2" class="data row10 col2" >76.4</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow10_col3" class="data row10 col3" >77.7</td>
#             </tr>
#             <tr>
#                         <th id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adlevel0_row11" class="row_heading level0 row11" >Shelton High School</th>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow11_col0" class="data row11 col0" >83.4</td>
#                         <td id="T_96def0b4_c8a5_11eb_b842_04d9f5f899adrow11_col1" class="data row11 col1" >82.9</td>
#                         <t

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
ninth_reading = clean_school_data.loc[clean_school_data['grade'] == '9th'].groupby('school_name')["reading_score"].mean()
tenth_reading = clean_school_data.loc[clean_school_data['grade'] == '10th'].groupby('school_name')["reading_score"].mean()
eleventh_reading = clean_school_data.loc[clean_school_data['grade'] == '11th'].groupby('school_name')["reading_score"].mean()
twelfth_reading = clean_school_data.loc[clean_school_data['grade'] == '12th'].groupby('school_name')["reading_score"].mean()

reading_scores = pd.DataFrame({
        "9th": ninth_reading,
        "10th": tenth_reading,
        "11th": eleventh_reading,
        "12th": twelfth_reading
})
reading_scores = reading_scores[['9th', '10th', '11th', '12th']]
reading_scores.index.name = "School"


reading_scores.style.format({'9th': '{:.1f}', 
                          "10th": '{:.1f}', 
                          "11th": "{:.1f}", 
                          "12th": "{:.1f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >9th</th>        <th class="col_heading level0 col1" >10th</th>        <th class="col_heading level0 col2" >11th</th>        <th class="col_heading level0 col3" >12th</th>    </tr>    <tr>        <th class="index_name level0" >School</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row0" class="row_heading level0 row0" >Bailey High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow0_col0" class="data row0 col0" >81.3</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow0_col1" class="data row0 col1" >80.9</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow0_col2" class="data row0 col2" >80.9</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow0_col3" class="data row0 col3" >80.9</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow1_col0" class="data row1 col0" >83.7</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow1_col1" class="data row1 col1" >84.3</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow1_col2" class="data row1 col2" >83.8</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow1_col3" class="data row1 col3" >84.3</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow2_col0" class="data row2 col0" >81.2</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow2_col1" class="data row2 col1" >81.4</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow2_col2" class="data row2 col2" >80.6</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow2_col3" class="data row2 col3" >81.4</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row3" class="row_heading level0 row3" >Ford High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow3_col0" class="data row3 col0" >80.6</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow3_col1" class="data row3 col1" >81.3</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow3_col2" class="data row3 col2" >80.4</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow3_col3" class="data row3 col3" >80.7</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row4" class="row_heading level0 row4" >Griffin High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow4_col0" class="data row4 col0" >83.4</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow4_col1" class="data row4 col1" >83.7</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow4_col2" class="data row4 col2" >84.3</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow4_col3" class="data row4 col3" >84.0</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow5_col0" class="data row5 col0" >80.9</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow5_col1" class="data row5 col1" >80.7</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow5_col2" class="data row5 col2" >81.4</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow5_col3" class="data row5 col3" >80.9</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row6" class="row_heading level0 row6" >Holden High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow6_col0" class="data row6 col0" >83.7</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow6_col1" class="data row6 col1" >83.3</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow6_col2" class="data row6 col2" >83.8</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow6_col3" class="data row6 col3" >84.7</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row7" class="row_heading level0 row7" >Huang High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow7_col0" class="data row7 col0" >81.3</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow7_col1" class="data row7 col1" >81.5</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow7_col2" class="data row7 col2" >81.4</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow7_col3" class="data row7 col3" >80.3</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row8" class="row_heading level0 row8" >Johnson High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow8_col0" class="data row8 col0" >81.3</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow8_col1" class="data row8 col1" >80.8</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow8_col2" class="data row8 col2" >80.6</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow8_col3" class="data row8 col3" >81.2</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row9" class="row_heading level0 row9" >Pena High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow9_col0" class="data row9 col0" >83.8</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow9_col1" class="data row9 col1" >83.6</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow9_col2" class="data row9 col2" >84.3</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow9_col3" class="data row9 col3" >84.6</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row10" class="row_heading level0 row10" >Rodriguez High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow10_col0" class="data row10 col0" >81.0</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow10_col1" class="data row10 col1" >80.6</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow10_col2" class="data row10 col2" >80.9</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow10_col3" class="data row10 col3" >80.4</td>
#             </tr>
#             <tr>
#                         <th id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adlevel0_row11" class="row_heading level0 row11" >Shelton High School</th>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow11_col0" class="data row11 col0" >84.1</td>
#                         <td id="T_9a118bc1_c8a5_11eb_a780_04d9f5f899adrow11_col1" class="data row11 col1" >83.4</td>
#                         <t

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
bins = [0, 584.999, 614.999, 644.999, 99999999]
group_name = ['< $585', "$585 - 614", "$615 - 644", "> $644"]
clean_school_data['spending_bins'] = pd.cut(clean_school_data['budget']/clean_school_data['size'], bins, labels = group_name)

by_spending = clean_school_data.groupby('spending_bins')

average_math = by_spending['math_score'].mean()
average_reading = by_spending['reading_score'].mean()
passing_math = clean_school_data[clean_school_data['math_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()
passing_read = clean_school_data[clean_school_data['reading_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()
overall_passing = clean_school_data[(clean_school_data['reading_score'] >= 70) & (clean_school_data['math_score'] >= 70)].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()

scores_by_spend = pd.DataFrame({
    "Average Math Score": average_math,
    "Average Reading Score": average_reading,
    '% Passing Math': passing_math,
    '% Passing Reading': passing_read,
    "Overall Passing Rate": overall_passing
            
})            

scores_by_spend = scores_by_spend[[
    "Average Math Score",
    "Average Reading Score",
    '% Passing Math',
    '% Passing Reading',
    "Overall Passing Rate"
]]

scores_by_spend.index.name = "Per Student Budget"
scores_by_spend = scores_by_spend.reindex(group_name)

scores_by_spend.style.format({'Average Math Score': '{:.1f}', 
                              'Average Reading Score': '{:.1f}', 
                              '% Passing Math': '{:.1%}', 
                              '% Passing Reading':'{:.1%}', 
                              'Overall Passing Rate': '{:.1%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Math Score</th>        <th class="col_heading level0 col1" >Average Reading Score</th>        <th class="col_heading level0 col2" >% Passing Math</th>        <th class="col_heading level0 col3" >% Passing Reading</th>        <th class="col_heading level0 col4" >Overall Passing Rate</th>    </tr>    <tr>        <th class="index_name level0" >Per Student Budget</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adlevel0_row0" class="row_heading level0 row0" >< $585</th>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow0_col0" class="data row0 col0" >83.4</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow0_col1" class="data row0 col1" >84.0</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow0_col2" class="data row0 col2" >93.7%</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow0_col3" class="data row0 col3" >96.7%</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow0_col4" class="data row0 col4" >90.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adlevel0_row1" class="row_heading level0 row1" >$585 - 614</th>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow1_col0" class="data row1 col0" >83.5</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow1_col1" class="data row1 col1" >83.8</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow1_col2" class="data row1 col2" >94.1%</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow1_col3" class="data row1 col3" >95.9%</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow1_col4" class="data row1 col4" >90.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adlevel0_row2" class="row_heading level0 row2" >$615 - 644</th>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow2_col0" class="data row2 col0" >78.1</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow2_col1" class="data row2 col1" >81.4</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow2_col2" class="data row2 col2" >71.4%</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow2_col3" class="data row2 col3" >83.6%</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow2_col4" class="data row2 col4" >60.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adlevel0_row3" class="row_heading level0 row3" >> $644</th>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow3_col0" class="data row3 col0" >77.0</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow3_col1" class="data row3 col1" >81.0</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow3_col2" class="data row3 col2" >66.2%</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow3_col3" class="data row3 col3" >81.1%</td>
#                         <td id="T_a8982de9_c8ee_11eb_91d3_04d9f5f899adrow3_col4" class="data row3 col4" >53.5%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
bins = [0, 999, 1999, 9999999]
group_name = ["Small (<1000)", "Medium (1000-2000)" , "Large (>2000)"]
clean_school_data['size_bins'] = pd.cut(clean_school_data['size'], bins, labels = group_name)

school_size = clean_school_data.groupby('size_bins')



average_math = school_size['math_score'].mean()
average_read = school_size['math_score'].mean()
passing_math = clean_school_data[clean_school_data['math_score'] >= 70].groupby('size_bins')['Student ID'].count()/school_size['Student ID'].count()
passing_read = clean_school_data[clean_school_data['reading_score'] >= 70].groupby('size_bins')['Student ID'].count()/school_size['Student ID'].count()
overall_passing = clean_school_data[(clean_school_data['reading_score'] >= 70) & (clean_school_data['math_score'] >= 70)].groupby('size_bins')['Student ID'].count()/school_size['Student ID'].count()

score_by_size = pd.DataFrame({
    "Average Math Score": average_math,
    "Average Reading Score": average_read,
    '% Passing Math': passing_math,
    '% Passing Reading': passing_read,
    "Overall Passing Rate": overall_passing
            
})

score_by_size = score_by_size[[
    "Average Math Score",
    "Average Reading Score",
    '% Passing Math',
    '% Passing Reading',
    "Overall Passing Rate"
]]

score_by_size.index.name = "Total Students"
score_by_size = score_by_size.reindex(group_name)


score_by_size.style.format({'Average Math Score': '{:.1f}', 
                              'Average Reading Score': '{:.1f}', 
                              '% Passing Math': '{:.1%}', 
                              '% Passing Reading':'{:.1%}', 
                              'Overall Passing Rate': '{:.1%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Math Score</th>        <th class="col_heading level0 col1" >Average Reading Score</th>        <th class="col_heading level0 col2" >% Passing Math</th>        <th class="col_heading level0 col3" >% Passing Reading</th>        <th class="col_heading level0 col4" >Overall Passing Rate</th>    </tr>    <tr>        <th class="index_name level0" >Total Students</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adlevel0_row0" class="row_heading level0 row0" >Small (<1000)</th>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow0_col0" class="data row0 col0" >83.8</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow0_col1" class="data row0 col1" >83.8</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow0_col2" class="data row0 col2" >94.0%</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow0_col3" class="data row0 col3" >96.0%</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow0_col4" class="data row0 col4" >90.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adlevel0_row1" class="row_heading level0 row1" >Medium (1000-2000)</th>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow1_col0" class="data row1 col0" >83.4</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow1_col1" class="data row1 col1" >83.4</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow1_col2" class="data row1 col2" >93.6%</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow1_col3" class="data row1 col3" >96.8%</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow1_col4" class="data row1 col4" >90.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adlevel0_row2" class="row_heading level0 row2" >Large (>2000)</th>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow2_col0" class="data row2 col0" >77.5</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow2_col1" class="data row2 col1" >77.5</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow2_col2" class="data row2 col2" >68.7%</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow2_col3" class="data row2 col3" >82.1%</td>
#                         <td id="T_4c7ee796_c8ef_11eb_9b9e_04d9f5f899adrow2_col4" class="data row2 col4" >56.6%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
school_type = clean_school_data.groupby("type")

average_math = school_size['math_score'].mean()
average_read = school_size['math_score'].mean()
passing_math = clean_school_data[clean_school_data['math_score'] >= 70].groupby('size_bins')['Student ID'].count()/school_size['Student ID'].count()
passing_read = clean_school_data[clean_school_data['reading_score'] >= 70].groupby('size_bins')['Student ID'].count()/school_size['Student ID'].count()
overall_passing = clean_school_data[(clean_school_data['reading_score'] >= 70) & (clean_school_data['math_score'] >= 70)].groupby('size_bins')['Student ID'].count()/school_size['Student ID'].count()
